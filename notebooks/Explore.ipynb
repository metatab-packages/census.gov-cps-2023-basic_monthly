# %%
# %load_ext autoreload
# %autoreload 2

import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline

mp.jupyter.init()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Current Population Survey, 2023
# `census.gov-cps-2023-basic_monthly-1.1.3` Last Update: 2023-03-06T16:35:08
#
# _The Current Population Survey (CPS) is the primary source of labor force statistics for the population of the United States._
#
#
# ## Documentation Links
#
# * [Subject Definitions](https://www.census.gov/programs-surveys/cps/technical-documentation/subject-definitions.html) Descriptions of major concepts.
# * [User Notes](https://www.census.gov/programs-surveys/cps/technical-documentation/user-notes.html) Various technical documentation.
# * [Homepage](https://www.census.gov/programs-surveys/cps.html)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * **[_labels](data/_labels.csv)**. Text descriptions of the integer values of categorical variables.
# * **[cps202301](data/cps202301.csv)**. Basic Monthly Current Population Survey, January 2023
#
# ## References
# ...

# %%
pkg.name
# Out:
# 'census.gov-cps-2023-basic_monthly-1.1.3'

# %%
df = pkg.resource('cps202301').labels()
# Out:
# {'gediv': {1: 'NEW ENGLAND',
#   2: 'MIDDLE ATLANTIC',
#   3: 'EAST NORTH CENTRAL',
#   4: 'WEST NORTH CENTRAL',
#   5: 'SOUTH ATLANTIC',
#   6: 'EAST SOUTH CENTRAL',
#   7: 'WEST SOUTH CENTRAL 8 MOUNTAIN 9 PACIFIC FILLER 1 92  \x96  92'},
#  'gereg': {1: 'NORTHEAST',
#   2: 'MIDWEST  ( FORMERLY NORTH CENTRAL )',
#   3: 'SOUTH',
#   4: 'WEST'},
#  'gestfips': {1: 'AL 30 MT',
#   2: 'AK 31 NE',
#   4: 'AZ 32 NV',
#   5: 'AR 33 NH',
#   6: 'CA 34 NJ',
#   8: 'CO 35 NM',
#   9: 'CT 36 NY',
#   10: 'DE 37 NC',
#   11: 'DC 38 ND',
#   12: 'FL 39 OH',
#   13: 'GA 40 OK',
#   15: 'HI 41 OR',
#   16: 'ID 42 PA',
#   17: 'IL 44 RI',
#   18: 'IN 45 SC',
#   19: 'IA 46 SD',
#   20: 'KS 47 TN',
#   21: 'KY 48 TX',
#   22: 'LA 49 UT',
#   23: 'ME 50 VT',
#   24: 'MD 51 VA',
#   25: 'MA 53 WA',
#   26: 'MI 54 WV',
#   27: 'MN 55 WI',
#   28: 'MS 56 WY',
#   29: 'MO FILLER 1 95  -  95'},
#  'gtcbsa': {0: 'NOT IDENTIFIED OR NONMETROPOLITAN'},
#  'gtcbsast': {1: 'PRINCIPAL CITY',
#   2: 'BALANCE',
# ...

# %%
df = pkg.resource('cps202301').dataframe(convert_categorical=True)
df.head()

# %%
df.hryear4.value_counts()

# %%
response="""
[
    "Puppies: So Cute, You Can't Resist!",
    "Cuddly Puppies: Cutest Companions Around!",
    "Puppy Love: The Most Adorable Feeling!",
    "Cute Puppies: A Pawsome Addition To Your Family!",
    "Puppy Power: Nothing Can Compare!",
    "Cuteness Overload: Get Yourself a Puppy!",
    "Puppies: Unconditional Love at Its Finest!",
    "Too Cute! Get a Puppy!",
    "Puppies: Wiggle Your Way Into Your Heart!",
    "Playful Pups: The Perfect Match for You!"
]"""

# %%
# !pip install openapi

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.Completion.create(
  model="text-davinci-003",
  prompt="I am a highly intelligent question answering bot. If you ask me a question that is rooted in truth, I will give you the answer. If you ask me a question that is nonsense, trickery, or has no clear answer, I will respond with \"Unknown\".\n\nQ: What is human life expectancy in the United States?\nA: Human life expectancy in the United States is 78 years.\n\nQ: Who was president of the United States in 1955?\nA: Dwight D. Eisenhower was president of the United States in 1955.\n\nQ: Which party did he belong to?\nA: He belonged to the Republican Party.\n\nQ: What is the square root of banana?\nA: Unknown\n\nQ: How does a telescope work?\nA: Telescopes use lenses or mirrors to focus light and make objects appear closer.\n\nQ: Where were the 1992 Olympics held?\nA: The 1992 Olympics were held in Barcelona, Spain.\n\nQ: How many squigs are in a bonk?\nA: Unknown\n\nQ: Where is the Valley of Kings?\nA:",
  temperature=0,
  max_tokens=100,
  top_p=1,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["\n"]
)

response
